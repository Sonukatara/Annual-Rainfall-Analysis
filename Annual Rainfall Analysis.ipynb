# %% [markdown]
# <h1 style="font-size:5rem; color:orange;"> Annual Rainfall Report </h1>

# %% [markdown]
# # RAINFALL ANALYSIS IN INDIA

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as py
import plotly.offline
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\manis\Documents\Rainfall in India 2000-2015.csv")

# %%
df.head()
# Out:
#                  SUBDIVISION  YEAR   JAN   FEB    MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  2000  53.0  59.0  171.3  218.1  422.8  357.0
# 1  ANDAMAN & NICOBAR ISLANDS  2001  89.0  15.7  143.3   30.1  705.3  370.7
# 2  ANDAMAN & NICOBAR ISLANDS  2002  10.6   0.0   11.5  100.2  366.7  358.3
# 3  ANDAMAN & NICOBAR ISLANDS  2003  44.3   7.9  149.2   19.4  296.3  159.9
# 4  ANDAMAN & NICOBAR ISLANDS  2004  54.5  35.9   36.5   41.6  505.1  423.9
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# 0  176.3  460.8  250.1  321.2  158.3  115.2  2763.2    112.0    812.2
# 1  341.3  469.0  334.4  267.6  222.6   91.8  3080.9    104.7    878.7
# 2  317.4  429.8  420.0  169.0  306.7  129.9  2620.2     10.7    478.4
# 3  494.9  379.4  371.9  310.4   74.1   48.0  2355.9     52.2    465.0
# 4  378.9  308.7  280.7  223.9  169.9    0.4  2460.1     90.4    583.2
#
#    Jun-Sep  Oct-Dec
# 0   1244.2    594.7
# 1   1515.4    582.0
# 2   1525.6    605.5
# 3   1406.1    432.5
# 4   1392.2    394.2

# %%
df.tail()
# Out:
#      SUBDIVISION  YEAR   JAN   FEB   MAR   APR    MAY    JUN    JUL    AUG  \
# 571  LAKSHADWEEP  2011   5.1   2.8   3.1  85.9  107.2  153.6  350.2  254.0
# 572  LAKSHADWEEP  2012  19.2   0.1   1.6  76.8   21.2  327.0  231.5  381.2
# 573  LAKSHADWEEP  2013  26.2  34.4  37.5   5.3   88.3  426.2  296.4  154.4
# 574  LAKSHADWEEP  2014  53.2  16.1   4.4  14.9   57.4  244.1  116.1  466.1
# 575  LAKSHADWEEP  2015   2.2   0.5   3.7  87.1  133.1  296.6  257.5  146.4
#
#        SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec
# 571  255.2  117.4  184.3   14.9  1533.7      7.9    196.2   1013.0    316.6
# 572  179.8  145.9   12.4    8.8  1405.5     19.3     99.6   1119.5    167.1
# 573  180.0   72.8   78.1   26.7  1426.3     60.6    131.1   1057.0    177.6
# 574  132.2  169.2   59.0   62.3  1395.0     69.3     76.7    958.5    290.5
# 575  160.4  165.4  231.0  159.0  1642.9      2.7    223.9    860.9    555.4

# %%
df.shape
# Out:
# (576, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576 entries, 0 to 575
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SUBDIVISION  576 non-null    object
#  1   YEAR         576 non-null    int64
#  2   JAN          575 non-null    float64
#  3   FEB          575 non-null    float64
#  4   MAR          576 non-null    float64
#  5   APR          576 non-null    float64
#  6   MAY          576 non-null    float64
#  7   JUN          576 non-null    float64
#  8   JUL          575 non-null    float64
#  9   AUG          576 non-null    float64
#  10  SEP          576 non-null    float64
#  11  OCT          576 non-null    float64
#  12  NOV          575 non-null    float64
#  13  DEC          575 non-null    float64
#  14  ANNUAL       573 non-null    float64
#  15  Jan-Feb      574 non-null    float64
#  16  Mar-May      576 non-null    float64
#  17  Jun-Sep      575 non-null    float64
#  18  Oct-Dec      575 non-null    float64
# dtypes: float64(17), int64(1), object(1)
# memory usage: 85.6+ KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                    SUBDIVISION  YEAR   JAN   FEB    MAR    APR    MAY    JUN  \
# 0    ANDAMAN & NICOBAR ISLANDS  2000  53.0  59.0  171.3  218.1  422.8  357.0
# 1    ANDAMAN & NICOBAR ISLANDS  2001  89.0  15.7  143.3   30.1  705.3  370.7
# 2    ANDAMAN & NICOBAR ISLANDS  2002  10.6   0.0   11.5  100.2  366.7  358.3
# 3    ANDAMAN & NICOBAR ISLANDS  2003  44.3   7.9  149.2   19.4  296.3  159.9
# 4    ANDAMAN & NICOBAR ISLANDS  2004  54.5  35.9   36.5   41.6  505.1  423.9
# ..                         ...   ...   ...   ...    ...    ...    ...    ...
# 571                LAKSHADWEEP  2011   5.1   2.8    3.1   85.9  107.2  153.6
# 572                LAKSHADWEEP  2012  19.2   0.1    1.6   76.8   21.2  327.0
# 573                LAKSHADWEEP  2013  26.2  34.4   37.5    5.3   88.3  426.2
# 574                LAKSHADWEEP  2014  53.2  16.1    4.4   14.9   57.4  244.1
# 575                LAKSHADWEEP  2015   2.2   0.5    3.7   87.1  133.1  296.6
#
#        JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# 0    176.3  460.8  250.1  321.2  158.3  115.2  2763.2    112.0    812.2
# 1    341.3  469.0  334.4  267.6  222.6   91.8  3080.9    104.7    878.7
# 2    317.4  429.8  420.0  169.0  306.7  129.9  2620.2     10.7    478.4
# 3    494.9  379.4  371.9  310.4   74.1   48.0  2355.9     52.2    465.0
# 4    378.9  308.7  280.7  223.9  169.9    0.4  2460.1     90.4    583.2
# ..     ...    ...    ...    ...    ...    ...     ...      ...      ...
# 571  350.2  254.0  255.2  117.4  184.3   14.9  1533.7      7.9    196.2
# 572  231.5  381.2  179.8  145.9   12.4    8.8  1405.5     19.3     99.6
# 573  296.4  154.4  180.0   72.8   78.1   26.7  1426.3     60.6    131.1
# 574  116.1  466.1  132.2  169.2   59.0   62.3  1395.0     69.3     76.7
# 575  257.5  146.4  160.4  165.4  231.0  159.0  1642.9      2.7    223.9
#
#      Jun-Sep  Oct-Dec
# 0     1244.2    594.7
# 1     1515.4    582.0
# 2     1525.6    605.5
# 3     1406.1    432.5
# 4     1392.2    394.2
# ..       ...      ...
# 571   1013.0    316.6
# 572   1119.5    167.1
# 573   1057.0    177.6
# 574    958.5    290.5
# 575    860.9    555.4
#
# [576 rows x 19 columns]>

# %%
df = df.rename(columns = {'SUBDIVISION':'STATE'})

# %%
df
# Out:
#                          STATE  YEAR   JAN   FEB    MAR    APR    MAY    JUN  \
# 0    ANDAMAN & NICOBAR ISLANDS  2000  53.0  59.0  171.3  218.1  422.8  357.0
# 1    ANDAMAN & NICOBAR ISLANDS  2001  89.0  15.7  143.3   30.1  705.3  370.7
# 2    ANDAMAN & NICOBAR ISLANDS  2002  10.6   0.0   11.5  100.2  366.7  358.3
# 3    ANDAMAN & NICOBAR ISLANDS  2003  44.3   7.9  149.2   19.4  296.3  159.9
# 4    ANDAMAN & NICOBAR ISLANDS  2004  54.5  35.9   36.5   41.6  505.1  423.9
# ..                         ...   ...   ...   ...    ...    ...    ...    ...
# 571                LAKSHADWEEP  2011   5.1   2.8    3.1   85.9  107.2  153.6
# 572                LAKSHADWEEP  2012  19.2   0.1    1.6   76.8   21.2  327.0
# 573                LAKSHADWEEP  2013  26.2  34.4   37.5    5.3   88.3  426.2
# 574                LAKSHADWEEP  2014  53.2  16.1    4.4   14.9   57.4  244.1
# 575                LAKSHADWEEP  2015   2.2   0.5    3.7   87.1  133.1  296.6
#
#        JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# 0    176.3  460.8  250.1  321.2  158.3  115.2  2763.2    112.0    812.2
# 1    341.3  469.0  334.4  267.6  222.6   91.8  3080.9    104.7    878.7
# 2    317.4  429.8  420.0  169.0  306.7  129.9  2620.2     10.7    478.4
# 3    494.9  379.4  371.9  310.4   74.1   48.0  2355.9     52.2    465.0
# 4    378.9  308.7  280.7  223.9  169.9    0.4  2460.1     90.4    583.2
# ..     ...    ...    ...    ...    ...    ...     ...      ...      ...
# 571  350.2  254.0  255.2  117.4  184.3   14.9  1533.7      7.9    196.2
# 572  231.5  381.2  179.8  145.9   12.4    8.8  1405.5     19.3     99.6
# 573  296.4  154.4  180.0   72.8   78.1   26.7  1426.3     60.6    131.1
# 574  116.1  466.1  132.2  169.2   59.0   62.3  1395.0     69.3     76.7
# 575  257.5  146.4  160.4  165.4  231.0  159.0  1642.9      2.7    223.9
#
#      Jun-Sep  Oct-Dec
# 0     1244.2    594.7
# 1     1515.4    582.0
# 2     1525.6    605.5
# 3     1406.1    432.5
# 4     1392.2    394.2
# ..       ...      ...
# 571   1013.0    316.6
# 572   1119.5    167.1
# 573   1057.0    177.6
# 574    958.5    290.5
# 575    860.9    555.4
#
# [576 rows x 19 columns]

# %%
plt.figure(figsize=(15,10))
sns.lineplot(x = 'YEAR', y= 'ANNUAL', hue = 'STATE', data = df)
plt.title('Annual Rainfall Received',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(21,8))
df.groupby(['STATE','YEAR'])['ANNUAL'].sum().sort_values(ascending=False).plot()
plt.grid()
plt.xlabel("State,Year",fontsize=15)
plt.ylabel("Annual Rainfall Received",fontsize=15)
plt.title('Highest Rainfall Year Data of States',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(15,10))
df.groupby(['STATE'])['ANNUAL'].sum().sort_values(ascending=False).head(15).plot(kind='bar', color = 'black')
plt.ylabel('Total Rainfall')
plt.title('Total Rainfall Data',fontsize=20)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,7))
df[['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG',
       'SEP', 'OCT', 'NOV', 'DEC']].mean().plot(kind= 'bar', color='red')
plt.xlabel('Months',fontsize=15)
plt.ylabel('Avg. Rainfall',fontsize=15)
plt.title('Avg. Monthly Rainfall Data',fontsize=25)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,2))
df[['STATE', 'Jan-Feb', 'Mar-May',
       'Jun-Sep', 'Oct-Dec']].groupby("STATE").mean().sort_values('Jun-Sep').plot.bar(width=0.5,edgecolor='k',align='center',stacked=True,figsize=(16,8))
plt.xlabel('STATE',fontsize=15)
plt.ylabel('Rainfall (in mm)',fontsize=15)
plt.title('Rainfall in States of India',fontsize=25)
plt.grid()

# %%
plt.rcParams['figure.figsize']=(18,8)
ax = sns.boxplot(x="STATE", y="ANNUAL", data=df, width=0.8,linewidth=3)
ax.set_xlabel('State',fontsize=20)
ax.set_ylabel('Annual Rainfall (in mm)',fontsize=20)
plt.title('Annual Rainfall in States of India',fontsize=30)
ax.tick_params(axis='x',labelsize=10,rotation=90)
ax.tick_params(axis='y',labelsize=10,rotation=0)
plt.grid()
plt.show()
